# %% [markdown]
# ### Making Categorical Plots
#
# - Frecuencia absoluta = conteo de los datos en cada categoría
# - Frecuencua relativa = valor porcentual de los datos en cada categoría
# Ambos frecuencias representan como se distribuyen los datos a través de las categorías (distribución de una variable categórica) ya que enumeran las posibles categorías y nos dicen con qué frecuencia se produce cada una de ellas.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('titanic')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df2 = sns.load_dataset('tips')

# %% [markdown]
# ## Bar plots
#
# - A barplot shows the relationship between a numeric and a categoric variable.
# - Compares categorical variables with frecuency, amounts, numerical data, etc.
# - Each **entity** of the categoric variable is represented as a bar.
# - The **size** of the bar represents its numeric value.
# -

# %%
df.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male  embark_town alive  alone
# 0        True  Southampton    no  False

# %%
plt.style.use('seaborn-whitegrid')

# %%
# Select categorical variable and compare it with a numerical one 
fig, ax = plt.subplots(2,2, figsize=(15,10))
class_counts = df['class'].value_counts()

sns.countplot(x='class',hue='who',data=df, ax=ax[0,0])
ax[0,0].set_title('People per class', fontsize=15)
ax[0,0].set_xlabel('Class', fontsize=15)
ax[0,0].set_ylabel('People', fontsize=15)
ax[0,0].tick_params(labelsize = 14)

sns.countplot(x='alive',hue='who',data=df, ax=ax[0,1])
ax[0,1].set_title('Survivors per population', fontsize=15)
ax[0,1].set_xlabel('ALive', fontsize=15)
ax[0,1].set_ylabel('People', fontsize=15)
ax[0,1].tick_params(labelsize = 14)

sns.barplot(x='class', y='age',hue='alive', data=df, ax = ax[1,0])
ax[1,0].set_title('Average age of survivors', fontsize=15)
ax[1,0].set_xlabel('Alive', fontsize=15)
ax[1,0].set_ylabel('Age', fontsize=15)
ax[1,0].tick_params(labelsize = 15);

sns.barplot(x='class', y='fare',hue='alive', data=df, ax = ax[1,1])
ax[1,1].set_title('Average fare per class', fontsize=15)
ax[1,1].set_xlabel('Alive', fontsize=15)
ax[1,1].set_ylabel('Fare', fontsize=15)
ax[1,1].tick_params(labelsize = 15);



fig.tight_layout()

# %%
df.head(10)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
#
#       who  adult_male  embark_town alive  alone
# 0     man        True  Southampton    no  False
# ...

# %%
fig, ax = plt.subplots(2,2, figsize=(15,10))
class_counts = df['class'].value_counts()

sns.countplot(x='alive',hue='who',data=df, ax=ax[0,0])
ax[0,0].set_title('Alive per population', fontsize=15)
ax[0,0].set_xlabel('Population', fontsize=15)
ax[0,0].set_ylabel('People', fontsize=15)
ax[0,0].tick_params(labelsize = 14)

sns.countplot(x='alive',hue='who',data=df, ax=ax[0,1])
ax[0,1].set_title('Survivors per who', fontsize=15)
ax[0,1].set_xlabel('ALive', fontsize=15)
ax[0,1].set_ylabel('People', fontsize=15)
ax[0,1].tick_params(labelsize = 14)

sns.barplot(x='alive', y='fare',hue='sex', data=df, ax = ax[1,0])
ax[1,0].set_title('fare paid for survivor', fontsize=15)
ax[1,0].set_xlabel('Alive', fontsize=15)
ax[1,0].set_ylabel('Companions', fontsize=15)
ax[1,0].tick_params(labelsize = 15);

sns.barplot(x='class', y='fare',hue='alive', data=df, ax = ax[1,1])
ax[1,1].set_title('Average fare of survivors', fontsize=15)
ax[1,1].set_xlabel('Alive', fontsize=15)
ax[1,1].set_ylabel('Fare', fontsize=15)
ax[1,1].tick_params(labelsize = 15);



fig.tight_layout()

# %%
df2.describe(include = 'all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
fig, ax = plt.subplots(figsize=(10,7))
sns.barplot(x='day', y='tip', data=df2, hue='sex',estimator=np.sum , stack=True);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-221-8ce6461b330f> in <module>
#       1 fig, ax = plt.subplots(figsize=(10,7))
# ----> 2 sns.barplot(x='day', y='tip', data=df2, hue='sex',estimator=np.sum , stack=True);
#
# ~\anaconda3\envs\Platzi - FundamentosAL\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\Platzi - FundamentosAL\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3185         ax = plt.gca()
#    3186
# -> 3187     plotter.plot(ax, kwargs)
#    3188     return ax
# ...

# %%
sns.s
